# %% [markdown]
# ### Name: Kevin J. Schwint
# #### Date: April 18 - May 11, 2023

# %% [markdown]
# # Project #3:
#
# # Web Scraped Data Analysis

# %% [markdown]
# # Web Scraping with requests and Beautiful Soup

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import numpy as np # linear algebra
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Create Dictionary with all NHL Hockey Teams and Print

# %%
nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
}

# Print the list with a header
print("{:<25} {:<20} {:<15}".format("Team", "Team Initials", "Division"))
for team, info in nhl_teams.items():
    initials = info["team_initials"]
    division = info["division"]
    print("{:<25} {:<20} {:<15}".format(team, initials, division))
# Out:
# Team                      Team Initials        Division
# Anaheim Ducks             ANA                  Pacific
# Arizona Coyotes           ARI                  Pacific
# Boston Bruins             BOS                  Atlantic
# Buffalo Sabres            BUF                  Atlantic
# Calgary Flames            CGY                  Pacific
# Carolina Hurricanes       CAR                  Metropolitan
# Chicago Blackhawks        CHI                  Central
# Colorado Avalanche        COL                  Central
# Columbus Blue Jackets     CBJ                  Metropolitan
# Dallas Stars              DAL                  Central
# Detroit Red Wings         DET                  Atlantic
# Edmonton Oilers           EDM                  Pacific
# Florida Panthers          FLA                  Atlantic
# Los Angeles Kings         LAK                  Pacific
# Minnesota Wild            MIN                  Central
# Montreal Canadiens        MTL                  Atlantic
# ...

# %% [markdown]
# ### "Hockey" Home Page url

# %%
# Define the URL to scrape
url = 'https://www.hockey-reference.com/?utm_source=hr&utm_medium=sr_xsite&utm_campaign=2023_01_srnav'
# Send a GET request to the URL
response = requests.get(url)
# Parse the HTML content
soup = bs(response.content, 'html.parser')

# %%
print(soup.prettify())
type(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="" data-version="klecko-" lang="en">
#  <head id="suppress_all_ads">
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <title>
#     Rate Limited Request (429 error) | Sports-Reference.com
#    </title>
#    <link href="https://www.sports-reference.com/429.html" rel="canonical"/>
#    <!-- CSS start -->
#    <style>
# ...

# %% [markdown]
# ### "NJ Devils" Home Page url

# %%
# Define the URL to scrape
url = 'https://www.hockey-reference.com/teams/NJD/index.html'
# Send a GET request to the URL
response = requests.get(url)
# Parse the HTML content
soup = bs(response.content, 'html.parser')

# %%
print(soup.prettify())
type(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="" data-version="klecko-" lang="en">
#  <head id="suppress_all_ads">
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <title>
#     Rate Limited Request (429 error) | Sports-Reference.com
#    </title>
#    <link href="https://www.sports-reference.com/429.html" rel="canonical"/>
#    <!-- CSS start -->
#    <style>
# ...

# %% [markdown]
# ### Scrape Data from "NJ Devils" Home Page and Print

# %%
# Define the URL to scrape
url = 'https://www.hockey-reference.com/teams/NJD/index.html'
# Send a GET request to the URL
response = requests.get(url)
# Parse the HTML content
soup = bs(response.content, 'html.parser')

# Find the roster table
roster_table = soup.find('table', {'id': 'roster'})

# Extract the roster data
roster_data = []
if roster_table:
    for row in roster_table.find_all('tr'):
        cells = row.find_all('td')
        if cells:
            player_name = cells[0].text.strip()
            player_country = cells[1].text.strip()
            player_position = cells[2].text.strip()
            player_age = cells[3].text.strip()
            player_salary = cells[10].text.strip()
            roster_data.append([player_name, player_country, player_position, player_age, player_salary])

# Print the roster data
if roster_data:
    print("Team Roster:")
    print("{:<30} {:<10} {:<10} {:<10} {:<10}".format("Player Name", "Country", "Position", "Age", "Salary"))
    for player in roster_data:
        print("{:<30} {:<10} {:<10} {:<10} {:<10}".format(player[0], player[1], player[2], player[3], player[4]))
else:
    print("No roster data found.")
    
roster_df = pd.DataFrame(roster_data)
# Out:
# Team Roster:
# Player Name                    Country    Position   Age        Salary
# Kevin Bahl                     ca         D          22         $750,000
# Nathan Bastian                 ca         F          25         $875,000
# Mackenzie Blackwood            ca         G          26         $4,125,000
# Jesper Boqvist                 se         F          24         $874,125
# Jesper Bratt                   se         F          24         $5,450,000
# Graeme Clarke                  us         F          21         $70,000
# Nico Daws                      de         G          22         $80,000
# Nolan Foote                    us         F          22         $70,000
# Ryan Graves                    ca         D          27         $4,000,000
# Brian Halonen                  us         F          24         $80,000
# Dougie Hamilton                ca         D          29         $3,300,000
# Erik Haula                     fi         F          31         $2,500,000
# ...

# %%
import os
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

def scrape_roster(team):
    # Define the URL to scrape
    url = f'https://www.hockey-reference.com/teams/{team_initials}/index.html'
    # Send a GET request to the URL
    response = requests.get(url)
    # Parse the HTML content
    soup = bs(response.content, 'html.parser')

    # Find the roster table
    roster_table = soup.find('table', {'id': 'roster'})

    # Extract the roster data
    roster_data = []
    if roster_table:
        for row in roster_table.find_all('tr'):
            cells = row.find_all('td')
            if cells:
                player_name = cells[0].text.strip()
                player_country = cells[1].text.strip()
                player_position = cells[2].text.strip()
                player_age = cells[3].text.strip()
                player_salary = cells[10].text.strip()
                roster_data.append([player_name, player_country, player_position, player_age, player_salary])

    # Print the roster data
    if roster_data:
        print("Team Roster:")
        print("{:<30} {:<10} {:<10} {:<10} {:<10}".format("Player Name", "Country", "Position", "Age", "Salary"))
        for player in roster_data:
            print("{:<30} {:<10} {:<10} {:<10} {:<10}".format(player[0], player[1], player[2], player[3], player[4]))
    else:
        print("No roster data found.")
    
    roster_df = pd.DataFrame(roster_data)
    return roster_df

# Example usage
team_initials = 'NYR'
roster_df = scrape_roster(team_initials)
roster_df
# Out:
# Team Roster:
# Player Name                    Country    Position   Age        Salary
# Filip Chytil                   cz         F          23         $2,600,000
# Adam Fox                       us         D          24         $11,000,000
# Barclay Goodrow                ca         F          29         $2,500,000
# Jaroslav Halak                 cs         G          37         $1,250,000
# Ben Harpur                     ca         D          28         $750,000
# Kaapo Kakko                    fi         F          21         $1,800,000
# Patrick Kane                   us         F          34         $725,000
# Chris Kreider                  us         F          31         $1,000,000
# Alexis Lafreniere              ca         F          21         $832,500
# Ryan Lindgren                  us         D          24         $3,000,000
# Niko Mikkola                   fi         D          26         $1,900,000
# ...

# %% [markdown]
# ### Create Separate .csv files for each NHL Team
# ### To be able to Contunue Working
# ### (Due to Status Code 429 - Too Many Requests)

# %%
import os
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
}

# Function to scrape roster data for a given team
def scrape_roster(team_initials):
    # Define the URL to scrape
    url = f'https://www.hockey-reference.com/teams/{team_initials}/index.html'
    # Send a GET request to the URL
    response = requests.get(url)
    # Parse the HTML content
    soup = bs(response.content, 'html.parser')

    # Find the roster table
    roster_table = soup.find('table', {'id': 'roster'})

    # Extract the roster data
    roster_data = []
    if roster_table:
        for row in roster_table.find_all('tr'):
            cells = row.find_all('td')
            if cells:
                player_name = cells[0].text.strip()
                player_country = cells[1].text.strip()
                player_position = cells[2].text.strip()
                player_age = cells[3].text.strip()
                player_salary = cells[10].text.strip()
                roster_data.append([player_name, player_country, player_position, player_age, player_salary])

    # Return the roster data as a Pandas DataFrame
    return pd.DataFrame(roster_data, columns=["Player Name", "Country", "Position", "Age", "Salary"])

# Loop through teams and create data files
for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    division = info["division"]

    # Scrape roster data for the team
    roster_df = scrape_roster(team_initials)
    
### Only Have to Run this Once

#   # Create a .csv data file for the team
#   file_name = f"{team_initials}_roster.csv"
#   roster_df.to_csv(file_name, index=False)  
#   # Set index=False to exclude the index column

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the URL to scrape
url = 'https://www.hockey-reference.com/teams/NJD/history.html'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the roster table
roster_table = soup.find('table', {'id': 'roster'})

# Extract the roster data
roster_data = []
if roster_table:
    for row in roster_table.find_all('tr'):
        cells = row.find_all('td')
        if cells:
            player_name = cells[0].text.strip()
            player_country = cells[1].text.strip()
            player_position = cells[2].text.strip()
            player_age = cells[3].text.strip()
            player_salary = cells[10].text.strip()
            roster_data.append([player_name, player_country, player_position, player_age, player_salary])

# Print the roster data
if roster_data:
    print("Team Roster:")
    print("{:<30} {:<10} {:<10} {:<10} {:<10}".format("Player Name", "Country", "Position", "Age", "Salary"))
    for player in roster_data:
        print("{:<30} {:<10} {:<10} {:<10} {:<10}".format(player[0], player[1], player[2], player[3], player[4]))
else:
    print("No roster data found.")

# Create DataFrame from roster data
roster_df = pd.DataFrame(roster_data)
# Out:
# No roster data found.

# %% [markdown]
# ### Can't seem to get this one above to work.

# %% [markdown]
# ## Collecting Player Information from Multiple Pages
#
# You will need to create a web scraping pipeline to do this.  Remember the main steps:
# 1. Gather links -- develop a strategy for scraping past posts
# 2. Scrape the same data from each page
# 3. Clean the data as necessary
#
# Save the information as one dictionary for each post and put all the posts in a list called `pipeline_list`.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def collect_player_names_df(team_name, start_year, end_year):
    """
    Collects player information from multiple web pages for a given team and multiple years.

    Args:
        team_name (str): The name of the team.
        start_year (int): The start year for collecting player information.
        end_year (int): The end year for collecting player information.

    Returns:
        pd.DataFrame: A Pandas DataFrame containing the collected player information.
    """
# Create an empty DataFrame to store the collected player information
    df = pd.DataFrame(columns=['Year', 'Player Name'])

# Loop through the years from start_year to end_year
    for year in range(start_year, end_year + 1):
# Construct the URL for the team's page for the current year
        url = f"https://www.hockey-reference.com/teams/{team_name}/{year}.html"

# Send a GET request to the URL
        response = requests.get(url)

# Parse the HTML content of the response
        soup = BeautifulSoup(response.content, 'html.parser')

# Extract player information from the parsed HTML
# Example: Extract player names
        player_names = soup.find_all('td', {'data-stat': 'player'})
        if player_names:
# Create a list to store player names for the current year
            year_player_names = []
            for player_name in player_names:
                year_player_names.append(player_name.text.strip())
# Create a DataFrame with the year_player_names list and the current year as columns
            year_df = pd.DataFrame({'Year': [year] * len(year_player_names), 'Player Name': year_player_names})
            # Append the year_df to the main df
            df = df.append(year_df, ignore_index=True)

# You can add more data extraction logic here based on your specific requirements

    return df

# New Jersey Develis - Last 5 Years
team_name = 'NJD'
start_year = 2019
end_year = 2023
player_info_df = collect_player_names_df(team_name, start_year, end_year)
print(player_info_df)
# Out:
# C:\Users\kjs1\AppData\Local\Temp\28\ipykernel_49120\2488825598.py:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(year_df, ignore_index=True)
#      Year          Player Name
# 0    2019       Kenny Agostino
# 1    2019        Joey Anderson
# 2    2019       Nathan Bastian
# 3    2019  Mackenzie Blackwood
# 4    2019          Brian Boyle
# ..    ...                  ...
# 554  2023          Ryan Graves
# 555  2023           Timo Meier
# 556  2023          Tomáš Tatar
# 557  2023        Tyce Thompson
# 558  2023   Yegor Sharangovich
#
# [559 rows x 2 columns]

# %%
player_info_df
# Out:
#      Year          Player Name
# 0    2019       Kenny Agostino
# 1    2019        Joey Anderson
# 2    2019       Nathan Bastian
# 3    2019  Mackenzie Blackwood
# 4    2019          Brian Boyle
# ..    ...                  ...
# 554  2023          Ryan Graves
# 555  2023           Timo Meier
# 556  2023          Tomáš Tatar
# 557  2023        Tyce Thompson
# 558  2023   Yegor Sharangovich
#
# [559 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup

def collect_player_information(team_name, start_year, end_year):
    """
    Collects player information from multiple web pages for a given team and multiple years.

    Args:
        team_name (str): The name of the team.
        start_year (int): The start year for collecting player information.
        end_year (int): The end year for collecting player information.

    Returns:
        list: A list of dictionaries containing the collected player information for each year.
    """
    # Create an empty list to store the collected player information for each year
    pipeline_list = []

    # Loop through the years from start_year to end_year
    for year in range(start_year, end_year + 1):
        # Construct the URL for the team's page for the current year
        url = f"https://www.hockey-reference.com/teams/{team_name}/{year}.html"

        # Send a GET request to the URL
        response = requests.get(url)

        # Parse the HTML content of the response
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract player information from the parsed HTML
        # Example: Extract player names
        player_names = soup.find_all('td', {'data-stat': 'player'})
        if player_names:
            # Create a dictionary to store player information for the current year
            year_player_info = {'Year': year, 'Player Names': []}
            for player_name in player_names:
                year_player_info['Player Names'].append(player_name.text.strip())
            # Append the year_player_info dictionary to the pipeline_list
            pipeline_list.append(year_player_info)

        # You can add more data extraction logic here based on your specific requirements

    return pipeline_list

# Example usage
team_name = 'NJD'
start_year = 2019
end_year = 2023
player_info_pipeline = collect_player_information(team_name, start_year, end_year)
print(player_info_pipeline)
# Out:
# [{'Year': 2019, 'Player Names': ['Kenny Agostino', 'Joey Anderson', 'Nathan Bastian', 'Mackenzie Blackwood', 'Brian Boyle', 'Jesper Bratt', 'Will Butcher', 'Connor Carrick', 'Blake Coleman', 'Jean-Sebastien Dea', 'Kurtis Gabriel', 'Brandon Gignac', 'Andy Greene\xa0(C)', 'Eric Gryba', 'Taylor Hall', 'Nico Hischier', 'Joshua Jacobs', 'Marcus Johansson', 'Keith Kinkaid', 'Nick Lappin', 'Ben Lovejoy', 'Michael McLeod', 'Mirco Müller', 'Ryan Murphy', 'Stefan Noesen', 'Kyle Palmieri', 'Blake Pietila', 'John Quenneville', 'Kevin Rooney', 'Steven Santini', 'Cory Schneider', 'Brett Seney', 'Damon Severson', 'Drew Stafford', 'Eric Tangradi', 'Sami Vatanen', 'Colton White', 'Miles Wood', 'Egor Yakovlev', 'Pavel Zacha', 'Travis Zajac', 'Kyle Palmieri', 'Nico Hischier', 'Travis Zajac', 'Damon Severson', 'Taylor Hall', 'Blake Coleman', 'Jesper Bratt', 'Will Butcher', 'Marcus Johansson', 'Pavel Zacha', 'Andy Greene', 'Miles Wood', 'Brian Boyle', 'Sami Vatanen', 'Brett Seney', 'Drew Stafford', 'Kenn
# ...

# %% [markdown]
# ### Player Statistics for a specified Team and a specified Year

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_player_data(url):
    """
    Extract player data from a given hockey-reference.com URL for a specific year.
    Returns a Pandas DataFrame with player information.
    """
    # Send a GET request to the URL
    response = requests.get(url)

    # Use BeautifulSoup to parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the table containing player stats
    table = soup.find('table', {'id': 'skaters'})

    # Extract the column headers
    headers = [th.text for th in table.find_all('th')]

    # Extract the player rows
    rows = []
    for tr in table.find_all('tr')[1:]:
        # Extract the player stats from each row
        data = [td.text for td in tr.find_all('td')]
        row = dict(zip(headers, data))
        rows.append(row)

    # Create a Pandas DataFrame from the rows
    df = pd.DataFrame(rows)

    return df

# Example usage
base_url = 'https://www.hockey-reference.com/teams/NJD/'
years = ['2019', '2020', '2021', '2022', '2023']
pipeline_list = []

for year in years:
    url = base_url + year + '.html'
    df = extract_player_data(url)
    pipeline_list.append(df)
    
# Concatenate the dataframes into one
all_data = pd.concat(pipeline_list, ignore_index=True)

# Print the resulting dataframe
print(all_data)
# Out:
#          Scoring Goals Assists Ice Time Point Shares   Rk Player   Age    Pos  \
# 0    NaN     NaN   NaN     NaN      NaN          NaN  NaN    NaN   NaN    NaN
# 1      0      RW    23      50       16           11  224   12.1  1343  18:09
# 2      0       C    30      47       14            3  160   10.6  1249  18:06
# 3      0       C    27      46       12            5  120   15.8  1542  19:16
# 4      1       D    28      39        8            3  146    7.5  1808  22:03
# ..   ...     ...   ...     ...      ...          ...  ...    ...   ...    ...
# 190    0      28    LW       2        0            0    0      0     0      1
# 191    0      27     C       4        0           -1    0      0     0      1
# 192    0      22     G      18        0            0    0      0     0      0
# 193    0      23    RW       2        0           -1    0      0     0      1
# 194   50                    82      769          277  376     94    10   2821
#
# ...

# %% [markdown]
# ### Check and Clean each Team Roster File (Manually One-by-One)

# %%
import pandas as pd

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
}

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

# Example usage: read data for team initials "NJD"
team_initials = "WSH"
data_team = read_datafile(team_initials)
print(team_initials)
print(data_team)  # Print the DataFrame
# Out:
# WSH
#     No.          Player Name Country Position  Age       Salary
# 0    27   Alexander Alexeyev      ru        D   23    $832,500
# 1    96   Nicolas Aube-Kubel      ca        F   26    $750,000
# 2    19    Nicklas Backstrom      se        F   35  $3,000,000
# 3    74         John Carlson      us        D   33  $4,000,000
# 4    97          Reid Cooper      ca        G   24  $1,000,000
# 5    26             Nic Dowd      us        F   32  $1,600,000
# 6    42     Martin Fehervary      sk        D   23    $832,500
# 7     1   Hardy Haman Aktell      se        D   24  $1,000,000
# 8    52           Matt Irwin      ca        D   35    $750,000
# 9     3          Nick Jensen      us        D   32  $2,000,000
# 10   35        Darcy Kuemper      ca        G   32  $4,000,000
# 11   92     Evgeny Kuznetsov      ru        F   30  $3,000,000
# 12   79     Charlie Lindgren      us        G   29  $1,200,000
# 13   39       Anthony Mantha      ca        F   28  $6,500,000
# ...

# %% [markdown]
# ### Create Combined Datafram for all Teams and Check Print

# %%
import pandas as pd

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
 }

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    df = read_datafile(team_initials)
    df['Team'] = team  # Assign team name to each player in the dataframe
    team_dfs.append(df)

# Combine all team dataframes into a single dataframe
combined_df = pd.concat(team_dfs, ignore_index=True)

# Convert 'Salary' column to numeric data type
combined_df['Salary'] = combined_df['Salary'].replace('[\$,]', '', regex=True).astype(float)

# Print the combined dataframe
print(combined_df)
# Out:
#       No.       Player Name Country Position   Age     Salary           Team
# 0    28.0   Nathan Beaulieu      ca        D  30.0   850000.0  Anaheim Ducks
# 1    13.0      Simon Benoit      ca        D  24.0   750000.0  Anaheim Ducks
# 2    39.0       Sam Carrick      ca        F  28.0   850000.0  Anaheim Ducks
# 3    44.0       Max Comtois      ca        F  24.0  1000000.0  Anaheim Ducks
# 4     1.0      Lukas Dostal      cz        G  22.0   832500.0  Anaheim Ducks
# ..    ...               ...     ...      ...   ...        ...            ...
# 828  88.0      Nate Schmidt      us        D  31.0  5000000.0  Winnipeg Jets
# 829  64.0     Logan Stanley      ca        D  24.0  1000000.0  Winnipeg Jets
# 830  28.0    Kevin Stenlund      se        F  26.0   750000.0  Winnipeg Jets
# 831  21.0  Dominic Toninato      us        F  28.0   750000.0  Winnipeg Jets
# 832  26.0     Blake Wheeler      us        F  36.0  6500000.0  Winnipeg Jets
#
# [833 rows x 7 columns]

# %% [markdown]
# ### Player with the Highest Salary, Team and Salary

# %%
import pandas as pd

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
 }

for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    df = read_datafile(team_initials)
    df['Team'] = team  # Assign team name to each player in the dataframe
    team_dfs.append(df)

# Combine all team dataframes into a single dataframe
combined_df = pd.concat(team_dfs, ignore_index=True)

# Convert 'Salary' column to numeric data type
combined_df['Salary'] = combined_df['Salary'].replace('[\$,]', '', regex=True).astype(float)

# Find the player with the highest salary
highest_salary_player = combined_df.loc[combined_df['Salary'].idxmax()]
player_name = highest_salary_player['Player Name']
team = highest_salary_player['Team']
salary = highest_salary_player['Salary']

# Format salary with a dollar sign
formatted_salary = '${:,.0f}'.format(salary)

# Print the player with the highest salary and their team
print("Player with the highest salary:")
print("Name:", player_name)
print("Team:", team)
print("Salary:", formatted_salary)
# Out:
# Player with the highest salary:
# Name: Darnell Nurse
# Team: Edmonton Oilers
# Salary: $12,000,000

# %% [markdown]
# ### Average Salary of the League
# ### Team with the Highest Average Salary
# ### Team with the Highest Average Salary

# %%
import pandas as pd

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
 }

for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    df = read_datafile(team_initials)
    df['Team'] = team  # Assign team name to each player in the dataframe
    team_dfs.append(df)

# Combine all team dataframes into a single dataframe
combined_df = pd.concat(team_dfs, ignore_index=True)

# Convert 'Salary' column to numeric data type
combined_df['Salary'] = combined_df['Salary'].replace('[\$,]', '', regex=True).astype(float)

# Calculate average salary for each team
average_salary_by_team = combined_df.groupby('Team')['Salary'].mean()

# Calculate average salary in the league
average_salary_in_league = combined_df['Salary'].mean()

# Find the team with the highest average salary
team_with_highest_average_salary = average_salary_by_team.idxmax()
highest_average_salary = average_salary_by_team.max()

# Find the team with the lowest average salary
team_with_lowest_average_salary = average_salary_by_team.idxmin()
lowest_average_salary = average_salary_by_team.min()

# Format the average salaries with a dollar sign
formatted_highest_average_salary = '${:,.0f}'.format(highest_average_salary)
formatted_lowest_average_salary = '${:,.0f}'.format(lowest_average_salary)
formatted_average_salary_in_league = '${:,.0f}'.format(average_salary_in_league)

# Print the average salary in the league
print("\nAverage salary in the league:")
print("Average Salary:", formatted_average_salary_in_league)

# Print the team with the highest average salary
print("\nTeam with the highest average salary:")
print("Team:", team_with_highest_average_salary)
print("Average Salary:", formatted_highest_average_salary)

# Print the team with the lowest average salary
print("\nTeam with the lowest average salary:")
print("Team:", team_with_lowest_average_salary)
print("Average Salary:", formatted_lowest_average_salary)

# Create a bar chart for the salary of each team
plt.figure(figsize=(10, 6))  # Set the figure size

# Plot the bar chart
average_salary_by_team.plot(kind='bar')

# Customize the chart
plt.title('Average Salary by Team')  # Set the chart title
plt.xlabel('Team')  # Set the x-axis label
plt.ylabel('Average Salary')  # Set the y-axis label

# Display the chart
plt.tight_layout()  # Adjust the layout
plt.show()
# Out:
# Average salary in the league:
# Average Salary: $2,221,649
#
# Team with the highest average salary:
# Team: Calgary Flames
# Average Salary: $3,295,652
#
# Team with the lowest average salary:
# Team: Toronto Maple Leafs
# Average Salary: $1,335,948

# %% [markdown]
# ### Position with the Highest Average Salary
# ### Position with the Lowest Average Salary

# %%
import pandas as pd

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
 }

for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    df = read_datafile(team_initials)
    df['Team'] = team  # Assign team name to each player in the dataframe
    team_dfs.append(df)

# Combine all team dataframes into a single dataframe
combined_df = pd.concat(team_dfs, ignore_index=True)

# Convert 'Salary' column to numeric data type
combined_df['Salary'] = combined_df['Salary'].str.replace('[\$,]', '', regex=True).astype(float)

# Calculate the average salary for each position
position_avg_salary = combined_df.groupby('Position')['Salary'].mean()

# Find the position with the highest average salary
highest_salary_position = position_avg_salary.idxmax()

# Find the position with the lowest average salary
lowest_salary_position = position_avg_salary.idxmin()

# Print the results
print("Position with the highest average salary:", highest_salary_position)
print("Position with the lowest average salary:", lowest_salary_position)
# Out:
# Position with the highest average salary: D
# Position with the lowest average salary: F

# %% [markdown]
# ### Country with the Most Players and
# ### Number of Players from that Country

# %%
import pandas as pd

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
 }

for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    df = read_datafile(team_initials)
    df['Team'] = team  # Assign team name to each player in the dataframe
    team_dfs.append(df)

# Combine all team dataframes into a single dataframe
combined_df = pd.concat(team_dfs, ignore_index=True)

# Count the occurrences of each country
country_counts = combined_df['Country'].value_counts()

# Find the country with the most players
country_with_most_players = country_counts.idxmax()
num_players = country_counts.max()

# Print the country with the most players
print("Country with the most players:")
print("Country:", country_with_most_players)
print("Number of Players:", num_players)

# Create a bar chart for the number of players from each country
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot the bar chart
country_counts.plot(kind='bar')

# Customize the chart
plt.title('Number of Players by Country')  # Set the chart title
plt.xlabel('Country')  # Set the x-axis label
plt.ylabel('Number of Players')  # Set the y-axis label

# Display the chart
plt.tight_layout()  # Adjust the layout
plt.show()
# Out:
# Country with the most players:
# Country: ca
# Number of Players: 344

# %% [markdown]
# ### Average Age in the League
# ### Team with the Youngest Players and Average Age of that Team
# ### Team with the Oldest Players and Average Age of that Team

# %%
import pandas as pd

# Create an empty list to store the dataframes
team_dfs = []

def read_datafile(team_initials):
    file_name = f"{team_initials}_roster.csv"
    df = pd.read_csv(file_name)
    return df  # Return the DataFrame

nhl_teams = {
    "Anaheim Ducks": {"team_initials": "ANA", "division": "Pacific"},
    "Arizona Coyotes": {"team_initials": "ARI", "division": "Pacific"},
    "Boston Bruins": {"team_initials": "BOS", "division": "Atlantic"},
    "Buffalo Sabres": {"team_initials": "BUF", "division": "Atlantic"},
    "Calgary Flames": {"team_initials": "CGY", "division": "Pacific"},
    "Carolina Hurricanes": {"team_initials": "CAR", "division": "Metropolitan"},
    "Chicago Blackhawks": {"team_initials": "CHI", "division": "Central"},
    "Colorado Avalanche": {"team_initials": "COL", "division": "Central"},
    "Columbus Blue Jackets": {"team_initials": "CBJ", "division": "Metropolitan"},
    "Dallas Stars": {"team_initials": "DAL", "division": "Central"},
    "Detroit Red Wings": {"team_initials": "DET", "division": "Atlantic"},
    "Edmonton Oilers": {"team_initials": "EDM", "division": "Pacific"},
    "Florida Panthers": {"team_initials": "FLA", "division": "Atlantic"},
    "Los Angeles Kings": {"team_initials": "LAK", "division": "Pacific"},
    "Minnesota Wild": {"team_initials": "MIN", "division": "Central"},
    "Montreal Canadiens": {"team_initials": "MTL", "division": "Atlantic"},
    "Nashville Predators": {"team_initials": "NSH", "division": "Central"},
    "New Jersey Devils": {"team_initials": "NJD", "division": "Metropolitan"},
    "New York Islanders": {"team_initials": "NYI", "division": "Metropolitan"},
    "New York Rangers": {"team_initials": "NYR", "division": "Metropolitan"},
    "Ottawa Senators": {"team_initials": "OTT", "division": "Atlantic"},
    "Philadelphia Flyers": {"team_initials": "PHI", "division": "Metropolitan"},
    "Pittsburgh Penguins": {"team_initials": "PIT", "division": "Metropolitan"},
    "San Jose Sharks": {"team_initials": "SJS", "division": "Pacific"},
    "Seattle Kraken": {"team_initials": "SEA", "division": "Pacific"},
    "St. Louis Blues": {"team_initials": "STL", "division": "Central"},
    "Tampa Bay Lightning": {"team_initials": "TBL", "division": "Atlantic"},
    "Toronto Maple Leafs": {"team_initials": "TOR", "division": "Atlantic"},
    "Vancouver Canucks": {"team_initials": "VAN", "division": "Pacific"},
    "Vegas Golden Knights": {"team_initials": "VEG", "division": "Pacific"},
    "Washington Capitals": {"team_initials": "WSH", "division": "Metropolitan"},
    "Winnipeg Jets": {"team_initials": "WPG", "division": "Central"}
 }

for team, info in nhl_teams.items():
    team_initials = info["team_initials"]
    df = read_datafile(team_initials)
    df['Team'] = team  # Assign team name to each player in the dataframe
    team_dfs.append(df)

# Combine all team dataframes into a single dataframe
combined_df = pd.concat(team_dfs, ignore_index=True)

# Calculate average age for the league
average_age_in_league = combined_df['Age'].mean()

# Calculate the average age for each team
team_avg_age = combined_df.groupby('Team')['Age'].mean()

# Find the team with the youngest players
youngest_team = team_avg_age.idxmin()
youngest_avg_age = team_avg_age.min()

# Find the team with the oldest players
oldest_team = team_avg_age.idxmax()
oldest_avg_age = team_avg_age.max()

# Format the average age with one decimal place
formatted_average_age_in_league = '{:.1f}'.format(average_age_in_league)
formatted_youngest_avg_age = '{:.1f}'.format(youngest_avg_age)
formatted_oldest_avg_age = '{:.1f}'.format(oldest_avg_age)

# Print the average age in the league
print("Average age in the league:")
print("Average Age:", formatted_average_age_in_league)

print()

# Print the team with the youngest players
print("Team with the youngest players:")
print("Team:", youngest_team)
print("Average Age:", formatted_youngest_avg_age)

print()

# Print the team with the oldest players
print("Team with the oldest players:")
print("Team:", oldest_team)
print("Average Age:", formatted_oldest_avg_age)

# Calculate average age for each team
average_age_by_team = combined_df.groupby('Team')['Age'].mean()

# Create a bar chart for the average age of each team
plt.figure(figsize=(12, 6))  # Set the figure size

# Plot the bar chart
average_age_by_team.plot(kind='bar')

# Customize the chart
plt.title('Average Age by Team')  # Set the chart title
plt.xlabel('Team')  # Set the x-axis label
plt.ylabel('Average Age')  # Set the y-axis label

# Display the chart
plt.tight_layout()  # Adjust the layout
plt.show()
# Out:
# Average age in the league:
# Average Age: 27.1
#
# Team with the youngest players:
# Team: New Jersey Devils
# Average Age: 24.7
#
# Team with the oldest players:
# Team: Pittsburgh Penguins
# Average Age: 30.0
